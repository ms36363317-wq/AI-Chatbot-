# %%
# !pip install -r requirements.txt

# %%
# !pip install colab-xterm

# %%
# !pip -q install langchain_community

# %%
# !pip install ollama

# %%
# !pip -q install langchain_community

# %%
llm_model = "gpt-3.5-turbo"

# %%
import colabxterm
# !ollama pull llama3.1:8b
# %reload_ext colabxterm

# %%
from langchain_community.llms import Ollama
llm_model = Ollama(model = "llama3.1:8b")
llm = Ollama(model = "llama3.1:8b")

# %%
from langchain_community.llms import Ollama
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from langchain.memory import ConversationBufferMemory

llm = Ollama(model='llama3.1:8b')

# %%
llm_model.invoke("Hello, tell me 3 names of red flowers.")
# Out:
# 'Here are three names of red flowers:\n\n1. Rose\n2. Tulip\n3. Poppy'

# %%
from langchain_community.llms import Ollama
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from langchain.memory import ConversationBufferMemory

llm = Ollama(model='llama3.1:8b')

memory = ConversationBufferMemory(memory_key="chat_history")

qa_prompt = PromptTemplate(
    input_variables=["chat_history", "question"],
template = """
You are a helpful assistant. Continue the conversation naturally.
Please keep your answer concise, no more than 10 words.

Chat history:
{chat_history}

User: {question}
Assistant:"""
)

qa_chain = LLMChain(
    llm=llm,
    prompt=qa_prompt,
    memory=memory
)
# Out:
# /tmp/ipython-input-1493552936.py:23: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use RunnableSequence, e.g., `prompt | llm` instead.
#   qa_chain = LLMChain(

# %%
print(qa_chain.run("Hi, who are you?"))
# Out:
# /tmp/ipython-input-4057687822.py:1: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use invoke instead.
#   print(qa_chain.run("Hi, who are you?"))
# I'm an online assistant here to help with anything.

# %%
# !pip install pyTelegramBotAPI
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.3/48.3 kB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.8/294.8 kB 8.0 MB/s eta 0:00:00
# ...

# %%
import telebot
from __main__ import qa_chain, memory

API_TOKEN = "8450801662:AAG0nwwF3j_lOq9xXD2e6WhKT_KoDuxfyRE"
bot = telebot.TeleBot(API_TOKEN)

@bot.message_handler(func=lambda message: True)
def echo_all(message):
    user_text = message.text
    response = qa_chain.invoke({"question": user_text})
    bot.reply_to(message, response['text'])

print("🤖 Bot is running...")
bot.polling()
# Out:
# 🤖 Bot is running...
